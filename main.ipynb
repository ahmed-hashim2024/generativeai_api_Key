# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmed-hashim2024/generativeai_api_Key/blob/main/Yet_another_copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai
import textwrap

# %%
GOOGLE_API_KEY = "AIzaSyABJHNB4FSG4649GhNhK43HnEL6-FDS442V11xCA"  # change this api key with your api ... you can created on ' https://aistudio.google.com/app/api-keys '
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('models/gemini-2.5-flash-lite')   # choise the modele you can choise on ' https://docs.cloud.google.com/vertex-ai/generative-ai/docs/model-garden/available-models '

# %%
question = " what is the full stack develober carear Summarize in 600 characters"

# %%
prompt = f" hi, {question} "
response = model.generate_content(prompt)

# %%
print(textwrap.fill(response.text, width=80))
